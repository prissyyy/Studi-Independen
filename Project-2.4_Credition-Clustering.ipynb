# %% [markdown]
# <a href="https://colab.research.google.com/github/prissyyy/Studi-Independen/blob/main/Project-2.4_Credition-Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Import data

# %%
# import libary
import pandas as pd
import seaborn as sns

# %%
# Import dataset
# !git clone https://github.com/prissyyy/Studi-Independen.git
# Out:
# Cloning into 'Studi-Independen'...
# remote: Enumerating objects: 756, done.
# remote: Counting objects: 100% (756/756), done.
# remote: Compressing objects: 100% (747/747), done.
# remote: Total 756 (delta 420), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (756/756), 46.24 MiB | 15.55 MiB/s, done.
# Resolving deltas: 100% (420/420), done.

# %%
# deklarasi variabel
data = '/content/Studi-Independen/Data_Set/konsumen.csv'

# %%
# import dataset dengan separatory (pemisah) ";" -->semicolon
df = pd.read_csv(data, sep=';')

# %%
df
# Out:
#        SALES DATE      TYPE MOTOR  ... KETERANGAN KEWARGANEGARAAN
# 0      08/08/2019     REVO FIT FI  ...        NaN             WNI
# 1      16/10/2019     REVO FIT FI  ...        NaN             WNI
# 2      07/10/2019     REVO FIT FI  ...        NaN             WNI
# 3      09/09/2019     REVO FIT FI  ...      SOPAN             WNI
# 4      07/10/2019     REVO FIT FI  ...        NaN             WNI
# ...           ...             ...  ...        ...             ...
# 18611  10/04/2019   CBR 250RR STD  ...       BAIK             WNI
# 18612  02/08/2019   CBR 250RR ABS  ...        NaN             WNI
# 18613  29/07/2019   CBR 250RR ABS  ...        NaN             WNI
# 18614  15/03/2019  SUPER CUB C125  ...        NaN             WNI
# 18615  10/04/2019  SUPER CUB C125  ...        NaN             WNI
#
# [18616 rows x 27 columns]

# %% [markdown]
# ## Data Exploration

# %%
# drop duplicate row
df = df.drop_duplicates()

# %%
# cek data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11406 entries, 0 to 18614
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SALES DATE              11406 non-null  object
#  1   TYPE MOTOR              11406 non-null  object
#  2   COLOR                   11406 non-null  object
#  3   KODE CUSTOMER           11406 non-null  object
#  4   JENIS KELAMIN           11406 non-null  object
#  5   TANGGAL LAHIR           11406 non-null  object
#  6   KECAMATAN SURAT         11406 non-null  object
#  7   KOTA SURAT              11406 non-null  object
#  8   PROPINSI                11406 non-null  object
#  9   STATUS RUMAH            11406 non-null  object
#  10  JENIS PENJUALAN STNK    11406 non-null  object
#  11  JENIS PENJUALAN SSU     11406 non-null  object
#  12  BESAR DP                6760 non-null   float64
#  13  BESAR CICILAN           6760 non-null   float64
#  14  LAMA CICILAN            6760 non-null   float64
#  15  AGAMA                   11406 non-null  object
#  16  PEKERJAAN               11406 non-null  object
#  17  PENGELUARAN             11406 non-null  object
#  18  PENDIDIKAN              11406 non-null  object
#  19  KEBERSEDIAAN DIHUBUNGI  11406 non-null  object
#  20  MERK MOTOR SBLMNYA      11406 non-null  object
#  21  TYPE MOTOR SBLMNYA      11406 non-null  object
#  22  SMH DIGUNAKAN UNTUK     11406 non-null  object
#  23  YG MENGGUNAKAN SMH      11406 non-null  object
#  24  HOBI                    11406 non-null  object
#  25  KETERANGAN              4411 non-null   object
#  26  KEWARGANEGARAAN         11402 non-null  object
# dtypes: float64(3), object(24)
# memory usage: 2.4+ MB

# %%
# cek null
df.isnull()
# Out:
#        SALES DATE  TYPE MOTOR  COLOR  ...   HOBI  KETERANGAN  KEWARGANEGARAAN
# 0           False       False  False  ...  False        True            False
# 1           False       False  False  ...  False        True            False
# 2           False       False  False  ...  False        True            False
# 3           False       False  False  ...  False       False            False
# 4           False       False  False  ...  False        True            False
# ...           ...         ...    ...  ...    ...         ...              ...
# 18551       False       False  False  ...  False        True            False
# 18552       False       False  False  ...  False        True            False
# 18609       False       False  False  ...  False       False            False
# 18611       False       False  False  ...  False       False            False
# 18614       False       False  False  ...  False        True            False
#
# [11406 rows x 27 columns]

# %%
# cek jumlah setiap type motor
df['TYPE MOTOR'].value_counts()
# Out:
# ALL NEW SCOOPY           3045
# VARIO 150                1311
# VARIO 125 CBS            1158
# BEAT SPORTY CBS           996
# VARIO 125 CBS ISS         961
# PCX 150 CBS               859
# BEAT SPORTY CBS ISS       731
# BEAT SPORTY CW            679
# PCX 150 ABS               312
# BEAT STREET CBS           298
# GENIO CBS                 227
# GENIO CBS ISS             201
# CB150R STREETFIRE SE       97
# NEW CBR 150R STD           93
# ADV150 CBS                 93
# NEW SUPRA X 125 FI CW      87
# CRF150L                    48
# CB150R STREETFIRE STD      32
# ADV150 ABS                 28
# REVO FIT FI                23
# CB150 VERZA CW             20
# ALL NEW SONIC 150 R        18
# REVO CW FI                 17
# NEW VARIO 125 CBS ISS      16
# NEW VARIO 150              14
# NEW CBR 150R ABS            9
# SUPRA GTR 150               8
# CB150 VERZA SW              4
# NEW SUPRA X 125 FI SW       4
# CBR 250RR STD               4
# FORZA                       3
# CBR 250RR ABS               3
# PCX HYBRID                  2
# ALL NEW CBR150R             2
# SUPER CUB C125              2
# BEAT POP CBS ISS            1
# Name: TYPE MOTOR, dtype: int64

# %%
# nilai unik
df['KODE CUSTOMER'].unique()
#DROP
# Out:
# array(['INDIVIDUAL'], dtype=object)

# %%
df['KETERANGAN'].value_counts()
# Out:
# SOPAN                      1213
# BAIK                        701
# RAMAH                       636
# KONSUMEN BAIK               461
# NON INDENT                  292
# I                           259
# PERSONAL                    230
# INDENT                      166
# 0                           166
# BAIK RAMAH                  147
# PENDIAM                      87
# MURAH SENYUM RAMAH           18
# BIASA                        10
# karakter                      8
# RAMAH BAIK                    3
# 1                             2
# RAMHA                         2
# ORANGNYA BAIK DAN RAMAH       2
# PERSONAL.                     1
# KONSUEMEN BAIK                1
# ORANGNYA BAIK HATI            1
# PRNDIAM                       1
# BAIM RAMAH                    1
# KONSUEMN BAIK                 1
# RAMAH BAHAGIA                 1
# BAIIK                         1
# Name: KETERANGAN, dtype: int64

# %%
df['PENGELUARAN'].value_counts()
# Out:
# RP 1.000.001,- S/D RP 1.500.000,-    3664
# RP 2.000.001,- S/D RP 3.000.000,-    3008
# RP 1.500.001,- S/D RP 2.000.000,-    2874
# RP 3.000.001,- S/D RP 4.000.000,-     853
# RP 700.001,- S/D RP 1.000.000,-       597
# <= RP 700.000,-                       364
# > RP 4.000.000,-                       46
# Name: PENGELUARAN, dtype: int64

# %%
# membuat variabel baru
df_con = df

# %%
# membuat variabel a
a = df['TYPE MOTOR'].unique()
a
# Out:
# array(['REVO FIT FI', 'REVO CW FI', 'NEW SUPRA X 125 FI SW',
#        'NEW SUPRA X 125 FI CW', 'BEAT POP CBS ISS',
#        'NEW VARIO 125 CBS ISS', 'BEAT SPORTY CW', 'BEAT STREET CBS',
#        'BEAT SPORTY CBS ISS', 'BEAT SPORTY CBS', 'ALL NEW SCOOPY',
#        'VARIO 125 CBS', 'VARIO 125 CBS ISS', 'GENIO CBS', 'GENIO CBS ISS',
#        'ALL NEW SONIC 150 R', 'SUPRA GTR 150', 'CB150 VERZA SW',
#        'CB150 VERZA CW', 'ALL NEW CBR150R', 'NEW CBR 150R STD',
#        'NEW CBR 150R ABS', 'CB150R STREETFIRE STD',
#        'CB150R STREETFIRE SE', 'CRF150L', 'PCX 150 CBS', 'PCX 150 ABS',
#        'PCX HYBRID', 'VARIO 150', 'ADV150 CBS', 'ADV150 ABS',
#        'CBR 250RR STD', 'CBR 250RR ABS', 'FORZA', 'SUPER CUB C125',
#        'NEW VARIO 150'], dtype=object)

# %%
b = [15110000, 16970000, 18455000, 19535000, 17365000, 21910000,
               16665000, 17365000, 17465000, 16865000, 20325000, 21005000,
               21910000, 17945000, 18415000, 23680000, 24280000, 20290000,
               20945000, 29700000, 29700000, 31700000, 29700000, 30700000,
               34745000, 30845000, 34445000, 43650000, 24565000, 35186000,
               38251000, 61700000, 72800000, 84645000, 73645000, 24715000]

# %%
# replace a ke harga motor dalam bentuk set
df_con = df_con.replace(a, b)

# %%
df_con
# Out:
#        SALES DATE  TYPE MOTOR  ... KETERANGAN KEWARGANEGARAAN
# 0      08/08/2019    15110000  ...        NaN             WNI
# 1      16/10/2019    15110000  ...        NaN             WNI
# 2      07/10/2019    15110000  ...        NaN             WNI
# 3      09/09/2019    15110000  ...      SOPAN             WNI
# 4      07/10/2019    15110000  ...        NaN             WNI
# ...           ...         ...  ...        ...             ...
# 18551  16/07/2019    24565000  ...        NaN             WNI
# 18552  15/07/2019    24565000  ...        NaN             WNI
# 18609  26/06/2019    61700000  ...      SOPAN             WNI
# 18611  10/04/2019    61700000  ...       BAIK             WNI
# 18614  15/03/2019    73645000  ...        NaN             WNI
#
# [11406 rows x 27 columns]

# %%
# drop fitur selection
df_con = df_con.drop(['SALES DATE', 'COLOR', 'KODE CUSTOMER',
                      'TANGGAL LAHIR', 'KECAMATAN SURAT',	'KOTA SURAT', 'PROPINSI',
                       'KEBERSEDIAAN DIHUBUNGI', 'MERK MOTOR SBLMNYA', 'TYPE MOTOR SBLMNYA', 'SMH DIGUNAKAN UNTUK',
                       'HOBI', 'KETERANGAN', 'KEWARGANEGARAAN', 'AGAMA'], axis=1)

# %%
sns.displot(df, x="JENIS PENJUALAN SSU")

# %%
sns.displot(df, x="JENIS PENJUALAN STNK")

# %%
df_credit=df_con[(df['JENIS PENJUALAN STNK'] == "CREDIT") & (df['JENIS PENJUALAN SSU'] == 'CREDIT')]

# %%
df_credit['LAMA CICILAN'].value_counts()
# Out:
# 35.0    4120
# 23.0    1445
# 11.0     554
# 17.0     257
# 29.0     255
# 33.0      35
# 30.0      22
# 32.0       8
# 34.0       6
# 36.0       2
# 19.0       1
# 31.0       1
# 3.0        1
# 2.0        1
# 24.0       1
# 13.0       1
# Name: LAMA CICILAN, dtype: int64

# %%
df_credit
# Out:
#        TYPE MOTOR JENIS KELAMIN  ...      PENDIDIKAN YG MENGGUNAKAN SMH
# 3        15110000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# 5        15110000     PEREMPUAN  ...        SLTP/SMP       SAYA SENDIRI
# 6        15110000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# 7        15110000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# 9        15110000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# ...           ...           ...  ...             ...                ...
# 18532    24565000     PEREMPUAN  ...  TIDAK TAMAT SD       SAYA SENDIRI
# 18533    24565000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# 18534    24565000     LAKI-LAKI  ...              SD       SAYA SENDIRI
# 18549    24565000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# 18609    61700000     PEREMPUAN  ...        SLTA/SMU       SAYA SENDIRI
#
# [6710 rows x 12 columns]

# %%
df_credit  = df_credit.drop_duplicates()
df_credit
# Out:
#        TYPE MOTOR JENIS KELAMIN  ...      PENDIDIKAN YG MENGGUNAKAN SMH
# 3        15110000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# 5        15110000     PEREMPUAN  ...        SLTP/SMP       SAYA SENDIRI
# 6        15110000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# 7        15110000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# 9        15110000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# ...           ...           ...  ...             ...                ...
# 18532    24565000     PEREMPUAN  ...  TIDAK TAMAT SD       SAYA SENDIRI
# 18533    24565000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# 18534    24565000     LAKI-LAKI  ...              SD       SAYA SENDIRI
# 18549    24565000     LAKI-LAKI  ...        SLTA/SMU       SAYA SENDIRI
# 18609    61700000     PEREMPUAN  ...        SLTA/SMU       SAYA SENDIRI
#
# [6549 rows x 12 columns]

# %%
sns.displot(df_credit, x="LAMA CICILAN")

# %%
df['PENDIDIKAN'].value_counts()
# Out:
# SLTA/SMU           8431
# SLTP/SMP           1133
# SD                  721
# AKADEMI/DIPLOMA     556
# SARJANA             448
# TIDAK TAMAT SD       93
# PASCA SARJANA        24
# Name: PENDIDIKAN, dtype: int64

# %%
df['STATUS RUMAH'].value_counts()
# Out:
# RUMAH SENDIRI                 9099
# RUMAH ORANG TUA / KELUARGA    2255
# RUMAH SEWA                      52
# Name: STATUS RUMAH, dtype: int64

# %%
df['YG MENGGUNAKAN SMH'].value_counts()
# Out:
# SAYA SENDIRI                 10477
# PASANGAN SUAMI ATAU ISTRI      611
# ANAK                           207
# LAIN-LAIN                      111
# Name: YG MENGGUNAKAN SMH, dtype: int64

# %% [markdown]
# One Hot Encode : 'Jenis Kelamin', 'Pekerjaan', 'YG MENGGUNAKAN SMH', 'PENGELUARAN'

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
pendidikan = df['PENDIDIKAN'].unique()
rumah = df['STATUS RUMAH'].unique()

# %%
pendidikan
# Out:
# array(['AKADEMI/DIPLOMA', 'SLTA/SMU', 'SLTP/SMP', 'SARJANA', 'SD',
#        'PASCA SARJANA', 'TIDAK TAMAT SD'], dtype=object)

# %%
rumah
# Out:
# array(['RUMAH SENDIRI', 'RUMAH ORANG TUA / KELUARGA', 'RUMAH SEWA'],
#       dtype=object)

# %%
df_credit = df_credit.replace(pendidikan, [5, 4, 3, 6, 2,
                                           7, 1])
df_credit = df_credit.replace(rumah, [3,2,1])

# %%
df_credit
# Out:
#        TYPE MOTOR JENIS KELAMIN  ...  PENDIDIKAN YG MENGGUNAKAN SMH
# 3        15110000     LAKI-LAKI  ...           4       SAYA SENDIRI
# 5        15110000     PEREMPUAN  ...           3       SAYA SENDIRI
# 6        15110000     LAKI-LAKI  ...           4       SAYA SENDIRI
# 7        15110000     LAKI-LAKI  ...           4       SAYA SENDIRI
# 9        15110000     LAKI-LAKI  ...           4       SAYA SENDIRI
# ...           ...           ...  ...         ...                ...
# 18532    24565000     PEREMPUAN  ...           1       SAYA SENDIRI
# 18533    24565000     LAKI-LAKI  ...           4       SAYA SENDIRI
# 18534    24565000     LAKI-LAKI  ...           2       SAYA SENDIRI
# 18549    24565000     LAKI-LAKI  ...           4       SAYA SENDIRI
# 18609    61700000     PEREMPUAN  ...           4       SAYA SENDIRI
#
# [6549 rows x 12 columns]

# %%
df_credit_cor = df_credit.corr()

# %%
df_credit_encode = pd.get_dummies(data=df_credit, columns=['JENIS KELAMIN','PEKERJAAN', 'YG MENGGUNAKAN SMH', 'PENGELUARAN'])

# %%
df_credit_encode
# Out:
#        TYPE MOTOR  ...  PENGELUARAN_RP 700.001,- S/D RP 1.000.000,-
# 3        15110000  ...                                            0
# 5        15110000  ...                                            1
# 6        15110000  ...                                            0
# 7        15110000  ...                                            0
# 9        15110000  ...                                            0
# ...           ...  ...                                          ...
# 18532    24565000  ...                                            0
# 18533    24565000  ...                                            0
# 18534    24565000  ...                                            0
# 18549    24565000  ...                                            0
# 18609    61700000  ...                                            0
#
# [6549 rows x 43 columns]

# %%
df_credit_encode = df_credit_encode.drop(['JENIS PENJUALAN STNK', 'JENIS PENJUALAN SSU'], axis=1)

# %% [markdown]
# ##Trial

# %%
from matplotlib import pyplot as plt

# %%
df_credit_encode
# Out:
#        TYPE MOTOR  ...  PENGELUARAN_RP 700.001,- S/D RP 1.000.000,-
# 3        15110000  ...                                            0
# 5        15110000  ...                                            1
# 6        15110000  ...                                            0
# 7        15110000  ...                                            0
# 9        15110000  ...                                            0
# ...           ...  ...                                          ...
# 18532    24565000  ...                                            0
# 18533    24565000  ...                                            0
# 18534    24565000  ...                                            0
# 18549    24565000  ...                                            0
# 18609    61700000  ...                                            0
#
# [6549 rows x 41 columns]

# %%
features_scaled
# Out:
# array([[0.        , 1.        , 0.0119266 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.        , 0.01743118, ..., 0.        , 0.        ,
#         1.        ],
#        [0.        , 1.        , 0.01467889, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.13597469, 1.        , 0.05688073, ..., 0.        , 0.        ,
#         0.        ],
#        [0.13597469, 1.        , 0.10183485, ..., 1.        , 0.        ,
#         0.        ],
#        [0.67002229, 1.        , 0.09174311, ..., 0.        , 0.        ,
#         0.        ]])

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
mmscaler = MinMaxScaler()
features_scaled = mmscaler.fit_transform(df_credit_encode)

# %%
inertia = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(features_scaled)
    kmeanModel.fit(features_scaled)
    inertia.append(kmeanModel.inertia_)

# %%
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.show()

# %%
kmeans = KMeans(n_clusters=4).fit(features_scaled)

# %%
labels = pd.DataFrame(kmeans.labels_)
df_credit_ = df_credit.drop(['JENIS PENJUALAN STNK', 'JENIS PENJUALAN SSU'], axis=1)
df_credit_ = df_credit_.reset_index(drop=True)
df_credit_ = pd.concat((df_credit_,labels),axis=1)
df_credit_ = df_credit_.rename({0:'labels'},axis=1)
df_credit_ = df_credit_.replace(b, a)

# %%
df_credit_.loc[df_credit_['labels']==0]
# Out:
#                  TYPE MOTOR JENIS KELAMIN  ...  YG MENGGUNAKAN SMH  labels
# 2               REVO FIT FI     LAKI-LAKI  ...        SAYA SENDIRI       0
# 3               REVO FIT FI     LAKI-LAKI  ...        SAYA SENDIRI       0
# 5               REVO FIT FI     LAKI-LAKI  ...        SAYA SENDIRI       0
# 14    NEW SUPRA X 125 FI CW     LAKI-LAKI  ...        SAYA SENDIRI       0
# 18    NEW SUPRA X 125 FI CW     LAKI-LAKI  ...        SAYA SENDIRI       0
# ...                     ...           ...  ...                 ...     ...
# 6524              VARIO 150     LAKI-LAKI  ...        SAYA SENDIRI       0
# 6528              VARIO 150     LAKI-LAKI  ...        SAYA SENDIRI       0
# 6536              VARIO 150     LAKI-LAKI  ...           LAIN-LAIN       0
# 6541              VARIO 150     LAKI-LAKI  ...        SAYA SENDIRI       0
# 6546              VARIO 150     LAKI-LAKI  ...        SAYA SENDIRI       0
#
# [1023 rows x 11 columns]

# %%
df_credit_.loc[df_credit_['labels']==3]
# Out:
#                  TYPE MOTOR JENIS KELAMIN  ...  YG MENGGUNAKAN SMH  labels
# 0               REVO FIT FI     LAKI-LAKI  ...        SAYA SENDIRI       3
# 4               REVO FIT FI     LAKI-LAKI  ...        SAYA SENDIRI       3
# 9                REVO CW FI     LAKI-LAKI  ...        SAYA SENDIRI       3
# 10               REVO CW FI     LAKI-LAKI  ...        SAYA SENDIRI       3
# 20    NEW SUPRA X 125 FI CW     LAKI-LAKI  ...        SAYA SENDIRI       3
# ...                     ...           ...  ...                 ...     ...
# 6522              VARIO 150     LAKI-LAKI  ...        SAYA SENDIRI       3
# 6525              VARIO 150     LAKI-LAKI  ...        SAYA SENDIRI       3
# 6531              VARIO 150     LAKI-LAKI  ...        SAYA SENDIRI       3
# 6534              VARIO 150     LAKI-LAKI  ...        SAYA SENDIRI       3
# 6538              VARIO 150     LAKI-LAKI  ...        SAYA SENDIRI       3
#
# [1260 rows x 11 columns]

# %%
df_credit_['labels'].value_counts()
# Out:
# 1    2837
# 2    1429
# 3    1260
# 0    1023
# Name: labels, dtype: int64

# %%
df_credit_encode
# Out:
#        TYPE MOTOR  ...  PENGELUARAN_RP 700.001,- S/D RP 1.000.000,-
# 3        15110000  ...                                            0
# 5        15110000  ...                                            1
# 6        15110000  ...                                            0
# 7        15110000  ...                                            0
# 9        15110000  ...                                            0
# ...           ...  ...                                          ...
# 18532    24565000  ...                                            0
# 18533    24565000  ...                                            0
# 18534    24565000  ...                                            0
# 18549    24565000  ...                                            0
# 18609    61700000  ...                                            0
#
# [6549 rows x 41 columns]

# %%
# normalization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df_credit_encode)
