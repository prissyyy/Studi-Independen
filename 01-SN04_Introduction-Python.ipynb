# %% [markdown]
# <a href="https://colab.research.google.com/github/prissyyy/Studi-Independen/blob/main/01-SN04_Introduction-Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Senin, 13 Sept 2021

# %% [markdown]
# **Perintah 1**

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Perintah 2**

# %%
print("Hallo Dunia")
print("Riset Bahasa")
# Out:
# Hallo Dunia
# Riset Bahasa

# %% [markdown]
# **Perintah 3**

# %%
bilangan1 = 20
bilangan2 = 10
print(bilangan1 - bilangan2)
# Out:
# 10

# %% [markdown]
# **Perintah 4**

# %%
contoh_list = ['Dewi','Budi','Cici','Linda','Cici']
print(contoh_list)
contoh_set = {'Dewi','Budi','Cici','Linda','Cici'}
print(contoh_set)
contoh_frozen_set = ({'Dewi','Budi','Cici','Linda','Cici'})
print(contoh_frozen_set)
# Out:
# ['Dewi', 'Budi', 'Cici', 'Linda', 'Cici']
# {'Cici', 'Linda', 'Dewi', 'Budi'}
# {'Cici', 'Linda', 'Dewi', 'Budi'}

# %% [markdown]
# **Perintah 5**

# %%
person = {'nama':'Prissy','pekerjaan':'Ambassador PT.Cicil Solusi Mitra Teknologi'}
print(person['nama'])
print(person['pekerjaan'])
# Out:
# Prissy
# Ambassador PT.Cicil Solusi Mitra Teknologi

# %% [markdown]
# **Perintah 6**

# %%
contoh_list = [1, 'dua', 3, 4.0, 5]
print(contoh_list[0])
print(contoh_list[3])
contoh_list = [1, 'dua', 3, 4.0, 5]
contoh_list[3] = 'empat'
print(contoh_list[3])
# Out:
# 1
# 4.0
# empat
